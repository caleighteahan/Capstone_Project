# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
from pathlib import Path
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor

# %%
file_path = Path("Data/cleaned_data.csv")
df= pd.read_csv(file_path)

# %%
df['delivery'] = df['transactions'].str.contains('delivery', case=False, na=False)
df['pickup'] = df['transactions'].str.contains('pickup', case=False, na=False)
df['restaurant_reservation'] = df['transactions'].str.contains('restaurant_reservation', case=False, na=False)

# Fill NaN values with False in the new columns
df['delivery'] = df['delivery'].fillna(False)
df['pickup'] = df['pickup'].fillna(False)
df['restaurant_reservation'] = df['restaurant_reservation'].fillna(False)

# %%
y = df['price']
x = df.drop(columns=['price', 'image_url', 'url', 'id', 'name', 'transactions'])

# %%
X= x.fillna(0)

# %%
X.head(20)
# Out:
#     is_closed  review_count  rating     group_city cuisines   latitude  \
# 0       False          6101     4.0  New York City  Italian  40.742101
# 1       False          5028     4.5  New York City  Italian  40.723088
# 2       False          4828     4.5  New York City  Italian  40.733798
# 3       False          4648     4.0  New York City  Italian  40.594715
# 4       False          4640     4.0  New York City  Italian  40.757498
# 5       False          3812     4.5  New York City  Mexican  40.742255
# 6       False          3317     4.0  New York City  Mexican  40.722930
# 7       False          3314     4.0  New York City  Italian  40.704930
# 8       False          3150     4.5  New York City  Italian  40.722766
# 9       False          3138     3.5  New York City  Italian  40.760830
# 10      False          2909     4.0  New York City  Italian  40.732063
# 11      False          2844     4.0  New York City  Mexican  40.561161
# 12      False          2823     4.5  New York City  Mexican  40.757507
# 13      False          2768     4.0  New York City  Italian  40.772193
# 14      False          2670     4.0  New York City  Italian  40.759876
# 15      False          2603     4.0  New York City  Italian  40.732283
# 16      False          2593     4.0  New York City  Italian  40.756410
# 17      False          2490     4.0  New York City  Italian  40.758230
# 18      False          2392     4.0  New York City  Italian  40.729431
# 19      False          2360     4.5  New York City  Italian  40.733720
#
#     longitude state  delivery  pickup  restaurant_reservation
# 0  -73.989922    NY      True    True                   False
# 1  -73.994530    NY      True    True                   False
# 2  -73.999774    NY      True    True                   False
# 3  -73.981316    NY      True    True                   False
# 4  -73.986653    NY      True    True                   False
# 5  -74.005958    NY      True   False                   False
# 6  -73.994190    NY      True    True                   False
# 7  -73.933990    NY      True    True                   False
# 8  -73.996233    NY     False    True                   False
# 9  -73.989810    NY      True    True                   False
# 10 -74.003655    NY      True    True                   False
# 11 -74.301079    NJ     False   False                   False
# 12 -73.987772    NY      True   False                   False
# 13 -73.955615    NY      True    True                    True
# 14 -73.986767    NY      True    True                   False
# 15 -73.999284    NY      True    True                   False
# 16 -73.985470    NY      True    True                   False
# 17 -73.988360    NY      True    True                   False
# 18 -73.984541    NY      True    True                   False
# 19 -74.005130    NY      True    True                   False

# %%
from sklearn import preprocessing
from sklearn import utils

lab = preprocessing.LabelEncoder()
y_transformed = lab.fit_transform(y)

# %%
y_transformed[:10]
# Out:
# array([2, 1, 2, 2, 2, 2, 2, 2, 2, 3], dtype=int64)

# %%
X =pd.get_dummies(X).astype(int)

# %%
X.dtypes
# Out:
# is_closed       int32
# review_count    int32
# rating          int32
# latitude        int32
# longitude       int32
#                 ...
# state_TN        int32
# state_TX        int32
# state_VA        int32
# state_WA        int32
# state_WI        int32
# Length: 90, dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_transformed, random_state=42)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)

X_test_scaled = X_scaler.transform(X_test)

# %%
model = RandomForestRegressor(n_estimators= 500, random_state=78)

# %%
model= model.fit(X_train_scaled, y_train)

# %%
predictions = model.predict(X_test_scaled)

# %%
print(predictions)
# Out:
# [2.012      1.822      1.976      ... 1.832      0.56475714 0.15131864]

# %%
#print(classification_report(y_test, predictions))

# %%
from sklearn import metrics
import numpy as np

#print('Mean Absolute Error (MAE):', metrics.mean_absolute_error(y_test, predictions))
#print('Mean Squared Error (MSE):', metrics.mean_squared_error(y_test, predictions))
#print('Root Mean Squared Error (RMSE):', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
#mape = np.mean(np.abs((y_test - predictions) / np.abs(y_test)))
#print('Mean Absolute Percentage Error (MAPE):', round(mape * 100, 2))
#print('Accuracy:', round(100*(1 - mape), 2))


# Calculate error metrics
mae = metrics.mean_absolute_error(y_test, predictions)
mse = metrics.mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
#mape = np.mean(np.abs((y_test - predictions) / y_test))
#accuracy = 100 * (1 - mape)

# Print results
print(f'Mean Absolute Error (MAE): {mae:.2f}')
print(f'Mean Squared Error (MSE): {mse:.2f}')
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')
#print(f'Mean Absolute Percentage Error (MAPE): {mape*100:.2f}%')
#print(f'Accuracy: {accuracy:.2f}%')
# Out:
# Mean Absolute Error (MAE): 0.44
# Mean Squared Error (MSE): 0.37
# Root Mean Squared Error (RMSE): 0.61

# %%
#cm = confusion_matrix(y_train, predictions)
#cm_df = pd.DataFrame(
    #cm ##index=[""], columns=['']
#)

ac_score= accuracy_score(y_train, predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\calei\OneDrive\Desktop\BC\Projects\Capstone_Project\Random_Forest_starter.ipynb Cell 19 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/calei/OneDrive/Desktop/BC/Projects/Capstone_Project/Random_Forest_starter.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> #cm = confusion_matrix(y_train, predictions)
#       <a href='vscode-notebook-cell:/c%3A/Users/calei/OneDrive/Desktop/BC/Projects/Capstone_Project/Random_Forest_starter.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> #cm_df = pd.DataFrame(
#       <a href='vscode-notebook-cell:/c%3A/Users/calei/OneDrive/Desktop/BC/Projects/Capstone_Project/Random_Forest_starter.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a>     #cm ##index=[""], columns=['']
#       <a href='vscode-notebook-cell:/c%3A/Users/calei/OneDrive/Desktop/BC/Projects/Capstone_Project/Random_Forest_starter.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> #)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/calei/OneDrive/Desktop/BC/Projects/Capstone_Project/Random_Forest_starter.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a> ac_score= accuracy_score(y_train, predictions)
#
# File c:\Users\calei\anaconda3\lib\site-packages\sklearn\utils\_param_validation.py:192, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
# --> 192     return func(*args, **kwargs)
#     193 except InvalidParameterError as e:
#     194     # When the function is just a wrapper around an estimator, we allow
#     195     # the function to delegate validation to the estimator, but we replace
#     196     # the name of the estimator by the name of the function in the error
#     197     # message to avoid confusion.
#     198     msg = re.sub(
#     199         r"parameter of \w+ must be",
#     200         f"parameter of {func.__qualname__} must be",
#     201         str(e),
#     202     )
#
# File c:\Users\calei\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:221, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     155 """Accuracy classification score.
#     156
#     157 In multilabel classification, this function computes subset accuracy:
#    (...)
#     217 0.5
#     218 """
#     220 # Compute accuracy for each possible representation
# --> 221 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     222 check_consistent_length(y_true, y_pred, sample_weight)
#     223 if y_type.startswith("multilabel"):
#
# File c:\Users\calei\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:86, in _check_targets(y_true, y_pred)
#      59 def _check_targets(y_true, y_pred):
#      60     """Check that y_true and y_pred belong to the same classification task.
#      61
#      62     This converts multiclass or binary types to a common shape, and raises a
#    (...)
#      84     y_pred : array or indicator matrix
#      85     """
# ---> 86     check_consistent_length(y_true, y_pred)
#      87     type_true = type_of_target(y_true, input_name="y_true")
#      88     type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File c:\Users\calei\anaconda3\lib\site-packages\sklearn\utils\validation.py:397, in check_consistent_length(*arrays)
#     395 uniques = np.unique(lengths)
#     396 if len(uniques) > 1:
# --> 397     raise ValueError(
#     398         "Found input variables with inconsistent numbers of samples: %r"
#     399         % [int(l) for l in lengths]
#     400     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [14358, 4787]
