# %%
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

# %%
file_path = Path("Data/cleaned_data2.csv")
df= pd.read_csv(file_path)

# %%
df['delivery'] = df['transactions'].str.contains('delivery', case=False, na=False)
df['pickup'] = df['transactions'].str.contains('pickup', case=False, na=False)
df['restaurant_reservation'] = df['transactions'].str.contains('restaurant_reservation', case=False, na=False)

# Fill NaN values with False in the new columns
df['delivery'] = df['delivery'].fillna(False)
df['pickup'] = df['pickup'].fillna(False)
df['restaurant_reservation'] = df['restaurant_reservation'].fillna(False)

# %%
new_york = []

for x in df['group_city']:
    if x == "New York City":
        new_york.append(x)
    else:
        new_york.append(0)



df['New York'] = np.array(new_york)

df= df.fillna(0)

df.head()
# Out:
#                        id                                         name  \
# 0  a0IET3_yCFcO36OqGSsisg                          Eataly NYC Flatiron
# 1  zj8Lq1T8KIC5zwFief15jg                          Prince Street Pizza
# 2  16ZnHpuaaBt92XWeJHCC5A                                   Olio e Più
# 3  vyoA8dxwScuMV_AsTcjQcg                        L & B Spumoni Gardens
# 4  22nKUyCIbpnzR6R3_g1ptQ  Carmine's Italian Restaurant - Times Square
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/1UDlnu...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/hN5xKw...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/0UszeE...      False
#
#                                                  url  review_count  rating  \
# 0  https://www.yelp.com/biz/eataly-nyc-flatiron-n...          6102     4.0
# 1  https://www.yelp.com/biz/prince-street-pizza-n...          5031     4.5
# 2  https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          4858     4.5
# 3  https://www.yelp.com/biz/l-and-b-spumoni-garde...          4647     4.0
# 4  https://www.yelp.com/biz/carmines-italian-rest...          4644     4.0
#
#        transactions  price     group_city cuisines   latitude  longitude  \
# 0  delivery, pickup      2  New York City  Italian  40.742101 -73.989922
# 1  delivery, pickup      1  New York City  Italian  40.723088 -73.994530
# 2  delivery, pickup      2  New York City  Italian  40.733798 -73.999774
# 3  delivery, pickup      2  New York City  Italian  40.594715 -73.981316
# 4  delivery, pickup      2  New York City  Italian  40.757498 -73.986653
#
#   state  delivery  pickup  restaurant_reservation       New York
# 0    NY      True    True                   False  New York City
# 1    NY      True    True                   False  New York City
# 2    NY      True    True                   False  New York City
# 3    NY      True    True                   False  New York City
# 4    NY      True    True                   False  New York City

# %%
def is_success(rating):
    return rating > 3.7

df['success'] = df['rating'].apply(is_success)

df.head()
# Out:
#                        id                                         name  \
# 0  a0IET3_yCFcO36OqGSsisg                          Eataly NYC Flatiron
# 1  zj8Lq1T8KIC5zwFief15jg                          Prince Street Pizza
# 2  16ZnHpuaaBt92XWeJHCC5A                                   Olio e Più
# 3  vyoA8dxwScuMV_AsTcjQcg                        L & B Spumoni Gardens
# 4  22nKUyCIbpnzR6R3_g1ptQ  Carmine's Italian Restaurant - Times Square
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/1UDlnu...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/hN5xKw...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/0UszeE...      False
#
#                                                  url  review_count  rating  \
# 0  https://www.yelp.com/biz/eataly-nyc-flatiron-n...          6102     4.0
# 1  https://www.yelp.com/biz/prince-street-pizza-n...          5031     4.5
# 2  https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          4858     4.5
# 3  https://www.yelp.com/biz/l-and-b-spumoni-garde...          4647     4.0
# 4  https://www.yelp.com/biz/carmines-italian-rest...          4644     4.0
#
#        transactions  price     group_city cuisines   latitude  longitude  \
# 0  delivery, pickup      2  New York City  Italian  40.742101 -73.989922
# 1  delivery, pickup      1  New York City  Italian  40.723088 -73.994530
# 2  delivery, pickup      2  New York City  Italian  40.733798 -73.999774
# 3  delivery, pickup      2  New York City  Italian  40.594715 -73.981316
# 4  delivery, pickup      2  New York City  Italian  40.757498 -73.986653
#
#   state  delivery  pickup  restaurant_reservation       New York  success
# 0    NY      True    True                   False  New York City     True
# 1    NY      True    True                   False  New York City     True
# 2    NY      True    True                   False  New York City     True
# 3    NY      True    True                   False  New York City     True
# 4    NY      True    True                   False  New York City     True

# %%
y = df['success']
X = df.drop(columns=['rating', 'success', 'image_url', 'url', 'id', 'name', 'group_city'])

X.head()
# Out:
#    is_closed  review_count      transactions  price cuisines   latitude  \
# 0      False          6102  delivery, pickup      2  Italian  40.742101
# 1      False          5031  delivery, pickup      1  Italian  40.723088
# 2      False          4858  delivery, pickup      2  Italian  40.733798
# 3      False          4647  delivery, pickup      2  Italian  40.594715
# 4      False          4644  delivery, pickup      2  Italian  40.757498
#
#    longitude state  delivery  pickup  restaurant_reservation       New York
# 0 -73.989922    NY      True    True                   False  New York City
# 1 -73.994530    NY      True    True                   False  New York City
# 2 -73.999774    NY      True    True                   False  New York City
# 3 -73.981316    NY      True    True                   False  New York City
# 4 -73.986653    NY      True    True                   False  New York City

# %%
from sklearn import preprocessing
from sklearn import utils

lab = preprocessing.LabelEncoder()
y_transformed = lab.fit_transform(y)

# %%
y_transformed[:10]
# Out:
# array([1, 1, 1, 1, 1, 1, 1, 1, 1, 0], dtype=int64)

# %%
X =pd.get_dummies(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_transformed, random_state=42)

# %%
scaler = StandardScaler()

X_scaler = scaler.fit(X_train)

X_train_scaled = X_scaler.transform(X_train)

X_test_scaled = X_scaler.transform(X_test)

# %%
model = RandomForestClassifier(n_estimators= 100, random_state=42)

# %%
model= model.fit(X_train_scaled, y_train)

# %%
predictions = model.predict(X_test_scaled)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.63      0.63      2892
#            1       0.64      0.65      0.65      2995
#
#     accuracy                           0.64      5887
#    macro avg       0.64      0.64      0.64      5887
# weighted avg       0.64      0.64      0.64      5887
