# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

# %%
df=pd.read_csv("Data/cleaned_data.csv")
df.head()
# Out:
#                        id                                         name  \
# 0  a0IET3_yCFcO36OqGSsisg                          Eataly NYC Flatiron
# 1  zj8Lq1T8KIC5zwFief15jg                          Prince Street Pizza
# 2  16ZnHpuaaBt92XWeJHCC5A                                   Olio e Più
# 3  vyoA8dxwScuMV_AsTcjQcg                        L & B Spumoni Gardens
# 4  22nKUyCIbpnzR6R3_g1ptQ  Carmine's Italian Restaurant - Times Square
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/1UDlnu...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/CUpPgz...      False
# 3  https://s3-media1.fl.yelpcdn.com/bphoto/hN5xKw...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/0UszeE...      False
#
#                                                  url  review_count  rating  \
# 0  https://www.yelp.com/biz/eataly-nyc-flatiron-n...          6101     4.0
# 1  https://www.yelp.com/biz/prince-street-pizza-n...          5028     4.5
# 2  https://www.yelp.com/biz/olio-e-pi%C3%B9-new-y...          4828     4.5
# 3  https://www.yelp.com/biz/l-and-b-spumoni-garde...          4648     4.0
# 4  https://www.yelp.com/biz/carmines-italian-rest...          4640     4.0
#
#        transactions  price     group_city cuisines   latitude  longitude state
# 0  delivery, pickup      2  New York City  Italian  40.742101 -73.989922    NY
# 1  delivery, pickup      1  New York City  Italian  40.723088 -73.994530    NY
# 2  pickup, delivery      2  New York City  Italian  40.733798 -73.999774    NY
# 3  delivery, pickup      2  New York City  Italian  40.594715 -73.981316    NY
# 4  delivery, pickup      2  New York City  Italian  40.757498 -73.986653    NY

# %%
y = df["rating"]
X=df.drop(columns=['rating', 'image_url', 'url', 'id', 'name'])

X = pd.get_dummies(X)

X= X.fillna(0)

X
# Out:
#        is_closed  review_count  price   latitude  longitude  \
# 0          False          6101      2  40.742101 -73.989922
# 1          False          5028      1  40.723088 -73.994530
# 2          False          4828      2  40.733798 -73.999774
# 3          False          4648      2  40.594715 -73.981316
# 4          False          4640      2  40.757498 -73.986653
# ...          ...           ...    ...        ...        ...
# 19140      False             8      0  35.724092 -78.547467
# 19141      False             8      0  35.866256 -78.574272
# 19142      False             8      0  35.854900 -78.584350
# 19143      False             8      1  35.707525 -78.618569
# 19144      False             8      0  35.850229 -78.615672
#
#        transactions_delivery  transactions_delivery, pickup  \
# 0                      False                           True
# 1                      False                           True
# 2                      False                          False
# 3                      False                           True
# 4                      False                           True
# ...                      ...                            ...
# 19140                   True                          False
# 19141                   True                          False
# 19142                  False                          False
# 19143                   True                          False
# 19144                  False                          False
#
#        transactions_delivery, pickup, restaurant_reservation  \
# 0                                                  False
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                  False
# ...                                                  ...
# 19140                                              False
# 19141                                              False
# 19142                                              False
# 19143                                              False
# 19144                                              False
#
#        transactions_delivery, restaurant_reservation  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 19140                                          False
# 19141                                          False
# 19142                                          False
# 19143                                          False
# 19144                                          False
#
#        transactions_delivery, restaurant_reservation, pickup  ...  state_ON  \
# 0                                                  False      ...     False
# 1                                                  False      ...     False
# 2                                                  False      ...     False
# 3                                                  False      ...     False
# 4                                                  False      ...     False
# ...                                                  ...      ...       ...
# 19140                                              False      ...     False
# 19141                                              False      ...     False
# 19142                                              False      ...     False
# 19143                                              False      ...     False
# 19144                                              False      ...     False
#
#        state_OR  state_PA  state_PE  state_SC  state_TN  state_TX  state_VA  \
# 0         False     False     False     False     False     False     False
# 1         False     False     False     False     False     False     False
# 2         False     False     False     False     False     False     False
# 3         False     False     False     False     False     False     False
# 4         False     False     False     False     False     False     False
# ...         ...       ...       ...       ...       ...       ...       ...
# 19140     False     False     False     False     False     False     False
# 19141     False     False     False     False     False     False     False
# 19142     False     False     False     False     False     False     False
# 19143     False     False     False     False     False     False     False
# 19144     False     False     False     False     False     False     False
#
#        state_WA  state_WI
# 0         False     False
# 1         False     False
# 2         False     False
# 3         False     False
# 4         False     False
# ...         ...       ...
# 19140     False     False
# 19141     False     False
# 19142     False     False
# 19143     False     False
# 19144     False     False
#
# [19145 rows x 102 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, stratify=y)

# %%
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1= 50
hidden_nodes_layer2= 50

nn = tf.keras.models.Sequential()

nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu')
)

nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu')
)

nn.add(tf.keras.layers.Dense(units=1, activation= 'sigmoid'))

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                5150
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 7751 (30.28 KB)
# Trainable params: 7751 (30.28 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
fit_model= nn.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 449/449 [==============================] - 1s 2ms/step - loss: -3109.3643 - accuracy: 0.0033
# Epoch 2/50
# 449/449 [==============================] - 1s 1ms/step - loss: -49169.8086 - accuracy: 0.0033
# Epoch 3/50
# 449/449 [==============================] - 1s 2ms/step - loss: -204588.7812 - accuracy: 0.0033
# Epoch 4/50
# 449/449 [==============================] - 1s 1ms/step - loss: -514438.8438 - accuracy: 0.0033
# Epoch 5/50
# 449/449 [==============================] - 1s 1ms/step - loss: -1007293.1250 - accuracy: 0.0033
# Epoch 6/50
# 449/449 [==============================] - 1s 2ms/step - loss: -1701462.3750 - accuracy: 0.0033
# Epoch 7/50
# 449/449 [==============================] - 1s 1ms/step - loss: -2611846.5000 - accuracy: 0.0033
# Epoch 8/50
# 449/449 [==============================] - 1s 1ms/step - loss: -3751417.0000 - accuracy: 0.0033
# Epoch 9/50
# 449/449 [==============================] - 1s 1ms/step - loss: -5131779.0000 - accuracy: 0.0033
# Epoch 10/50
# 449/449 [==============================] - 1s 1ms/step - loss: -6763328.5000 - accuracy: 0.0033
# Epoch 11/50
# 449/449 [==============================] - 1s 1ms/step - loss: -8656163.0000 - accuracy: 0.0033
# Epoch 12/50
# 449/449 [==============================] - 1s 2ms/step - loss: -10819572.0000 - accuracy: 0.0033
# Epoch 13/50
# 449/449 [==============================] - 1s 1ms/step - loss: -13264740.0000 - accuracy: 0.0033
# Epoch 14/50
# 449/449 [==============================] - 1s 1ms/step - loss: -16004962.0000 - accuracy: 0.0033
# Epoch 15/50
# 449/449 [==============================] - 1s 1ms/step - loss: -19050682.0000 - accuracy: 0.0033
# Epoch 16/50
# 449/449 [==============================] - 1s 1ms/step - loss: -22414536.0000 - accuracy: 0.0033
# Epoch 17/50
# 449/449 [==============================] - 1s 1ms/step - loss: -26108976.0000 - accuracy: 0.0033
# Epoch 18/50
# 449/449 [==============================] - 1s 1ms/step - loss: -30144742.0000 - accuracy: 0.0033
# Epoch 19/50
# 449/449 [==============================] - 1s 1ms/step - loss: -34535584.0000 - accuracy: 0.0033
# Epoch 20/50
# 449/449 [==============================] - 1s 1ms/step - loss: -39290548.0000 - accuracy: 0.0033
# Epoch 21/50
# 449/449 [==============================] - 1s 1ms/step - loss: -44419956.0000 - accuracy: 0.0033
# Epoch 22/50
# 449/449 [==============================] - 1s 1ms/step - loss: -49939024.0000 - accuracy: 0.0033
# Epoch 23/50
# 449/449 [==============================] - 1s 1ms/step - loss: -55862060.0000 - accuracy: 0.0033
# Epoch 24/50
# 449/449 [==============================] - 1s 1ms/step - loss: -62196020.0000 - accuracy: 0.0033
# Epoch 25/50
# 449/449 [==============================] - 1s 1ms/step - loss: -68948944.0000 - accuracy: 0.0033
# Epoch 26/50
# 449/449 [==============================] - 1s 1ms/step - loss: -76141576.0000 - accuracy: 0.0033
# Epoch 27/50
# 449/449 [==============================] - 1s 1ms/step - loss: -83780200.0000 - accuracy: 0.0033
# Epoch 28/50
# 449/449 [==============================] - 1s 1ms/step - loss: -91876688.0000 - accuracy: 0.0033
# Epoch 29/50
# 449/449 [==============================] - 1s 1ms/step - loss: -100446232.0000 - accuracy: 0.0033
# Epoch 30/50
# 449/449 [==============================] - 1s 1ms/step - loss: -109496632.0000 - accuracy: 0.0033
# Epoch 31/50
# 449/449 [==============================] - 1s 1ms/step - loss: -119042024.0000 - accuracy: 0.0033
# Epoch 32/50
# 449/449 [==============================] - 1s 1ms/step - loss: -129097368.0000 - accuracy: 0.0033
# Epoch 33/50
# 449/449 [==============================] - 1s 2ms/step - loss: -139659712.0000 - accuracy: 0.0033
# Epoch 34/50
# 449/449 [==============================] - 1s 1ms/step - loss: -150746032.0000 - accuracy: 0.0033
# Epoch 35/50
# 449/449 [==============================] - 1s 1ms/step - loss: -162375200.0000 - accuracy: 0.0033
# Epoch 36/50
# 449/449 [==============================] - 1s 1ms/step - loss: -174556464.0000 - accuracy: 0.0033
# Epoch 37/50
# 449/449 [==============================] - 1s 1ms/step - loss: -187294608.0000 - accuracy: 0.0033
# Epoch 38/50
# 449/449 [==============================] - 1s 1ms/step - loss: -200598768.0000 - accuracy: 0.0033
# Epoch 39/50
# 449/449 [==============================] - 1s 1ms/step - loss: -214490960.0000 - accuracy: 0.0033
# Epoch 40/50
# 449/449 [==============================] - 1s 1ms/step - loss: -228983008.0000 - accuracy: 0.0033
# Epoch 41/50
# 449/449 [==============================] - 1s 1ms/step - loss: -244084960.0000 - accuracy: 0.0033
# Epoch 42/50
# 449/449 [==============================] - 1s 1ms/step - loss: -259811088.0000 - accuracy: 0.0033
# Epoch 43/50
# 449/449 [==============================] - 1s 1ms/step - loss: -276164704.0000 - accuracy: 0.0033
# Epoch 44/50
# 449/449 [==============================] - 1s 1ms/step - loss: -293152384.0000 - accuracy: 0.0033
# Epoch 45/50
# 449/449 [==============================] - 1s 1ms/step - loss: -310795072.0000 - accuracy: 0.0033
# Epoch 46/50
# 449/449 [==============================] - 1s 1ms/step - loss: -329103040.0000 - accuracy: 0.0033
# Epoch 47/50
# 449/449 [==============================] - 1s 1ms/step - loss: -348094912.0000 - accuracy: 0.0033
# Epoch 48/50
# 449/449 [==============================] - 1s 1ms/step - loss: -367766400.0000 - accuracy: 0.0033
# Epoch 49/50
# 449/449 [==============================] - 1s 1ms/step - loss: -388119648.0000 - accuracy: 0.0033
# Epoch 50/50
# 449/449 [==============================] - 1s 1ms/step - loss: -409193408.0000 - accuracy: 0.0033

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 150/150 - 0s - loss: -4.2025e+08 - accuracy: 0.0033 - 246ms/epoch - 2ms/step
# Loss: -420245568.0, Accuracy: 0.0033423856366425753
