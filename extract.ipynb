# %%
import requests
import pandas as pd
# Import API key
from api import API_key

# %%
url = "https://api.yelp.com/v3/businesses/search"
headers = {
        'Authorization': 'Bearer ' + API_key,
        'Content-Type': 'application/json'
    }

# %%
restaurants= []

# %%
city = "New York City"
params = {'location': city,
    'limit': 50,
    'sort_by': 'review_count',
    'term': 'food',
    'categories':'mexican,tex-mex,italian'
    }
response = requests.get(url,  headers=headers, params=params).json()
if 'businesses' in response:
    restaurant_list = response['businesses']
    for r in restaurant_list:
        r['group_city'] = city
    restaurants.extend(restaurant_list)
print(restaurants)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 11
#       9 if 'businesses' in response:
#      10     restaurant = response['businesses']
# ---> 11     restaurant['group_city'] = city
#      12     restaurants.extend(restaurant)
#      13 print(restaurants)
#
# TypeError: list indices must be integers or slices, not str

# %%
def call_api(cities, offsets):
    for city in cities:
        print(f'Getting data for city: {city}')
        for offset in offsets:
            print(f'Getting offset: {offset}')
            params = {'location': city,
                'limit': 50,
                'offset': offset,
                'sort_by': 'review_count',
                'term': 'food',
                'categories':'mexican,tex-mex,italian'
                }
            response = requests.get(url,  headers=headers, params=params).json()
            if 'businesses' in response:
                restaurant = response['businesses']
                restaurant['group_city'] = city
                restaurants.extend(restaurant)

# %%
cities = [
    "New York City",
    "Los Angeles",
    "Chicago",
    "Houston",
    "Phoenix",
    "Philadelphia",
    "San Antonio",
    "San Diego",
    "Dallas",
    "San Jose",
    "Austin",
    "Jacksonville",
    "Fort Worth",
    "Columbus",
    "San Francisco",
    "Charlotte",
    "Indianapolis",
    "Seattle",
    "Denver",
    "Washington, D.C.",
    "Boston",
    "El Paso",
    "Nashville",
    "Detroit",
    "Oklahoma City",
    "Portland",
    "Las Vegas",
    "Memphis",
    "Louisville",
    "Baltimore",
    "Milwaukee",
    "Albuquerque",
    "Tucson",
    "Fresno",
    "Sacramento",
    "Kansas City",
    "Atlanta",
    "Colorado Springs",
    "Omaha",
    "Raleigh"
]
offsets = [0,51,101,151,201,251,301,351,401,451]
# Calling extract api
call_api(cities, offsets)
# Out:
# Getting data for city: New York City
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Los Angeles
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Chicago
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Houston
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Phoenix
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Philadelphia
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: San Antonio
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: San Diego
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Dallas
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: San Jose
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Austin
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Jacksonville
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Fort Worth
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Columbus
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: San Francisco
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Charlotte
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Indianapolis
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Seattle
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Denver
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Washington, D.C.
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Boston
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: El Paso
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Nashville
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Detroit
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Oklahoma City
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Portland
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Las Vegas
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Memphis
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Louisville
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Baltimore
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Milwaukee
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Albuquerque
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Tucson
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Fresno
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Sacramento
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Kansas City
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Atlanta
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Colorado Springs
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Omaha
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451
# Getting data for city: Raleigh
# Getting offset: 0
# Getting offset: 51
# Getting offset: 101
# Getting offset: 151
# Getting offset: 201
# Getting offset: 251
# Getting offset: 301
# Getting offset: 351
# Getting offset: 401
# Getting offset: 451

# %%
df = pd.DataFrame(restaurants)

# %%
csv_file_path = 'data.csv'

# Convert and save the DataFrame to CSV
df.to_csv(csv_file_path, index=False)
